# %% [markdown]
# <a href="https://colab.research.google.com/github/janduplessis883/jan-linear-regression-population-health-01/blob/main/Linear_Regression_Population_Health%20-%2002.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Linear Regression**: - Polulation Health
# Jan du Plessis - *Data Science #1052*<BR>
# Dataset: `jan-datasets/TGP2.csv`

# %% [markdown]
# ### Data Prep

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns
 
# Set style to 'seaborn' - high resolution graphs
plt.style.use('seaborn')
# %config InlineBackend.figure_format = 'retina'

# %%
df = pd.read_csv('/content/TGP2.csv')
df
# Out:
#          REGDATE     SEX  AGE    SYS  DIAS EGFR   ALT   FERR  CHOL
# 0     17/08/2010  Female   13    NaN   NaN  NaN   NaN    9.0   NaN
# 1     09/09/2010  Female   12    NaN   NaN  NaN   NaN    NaN   NaN
# 2     17/07/2014  Female    8    NaN   NaN  NaN   NaN    NaN   NaN
# 3     14/10/2011  Female   11    NaN   NaN  NaN   NaN    NaN   NaN
# 4     07/05/2020  Female    2    NaN   NaN  NaN   NaN    NaN   NaN
# ...          ...     ...  ...    ...   ...  ...   ...    ...   ...
# 8810  15/09/2017  Female   39    NaN   NaN  NaN   NaN    NaN   NaN
# 8811  15/10/2019    Male   39  128.0  81.0  NaN   NaN    NaN   NaN
# 8812  25/09/2019  Female   26  113.0  69.0   90  21.0   13.0   4.5
# 8813  10/07/2018    Male   47  120.0  78.0   90  43.0  166.0   5.0
# 8814  20/01/2022    Male   25    NaN   NaN  NaN   NaN    NaN   NaN
#
# [8815 rows x 9 columns]

# %%
df = df.replace(0, np.nan)

# %%
df['REGDATE'] = pd.to_datetime(df['REGDATE'], format='%d/%m/%Y')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8815 entries, 0 to 8814
# Data columns (total 9 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   REGDATE  8815 non-null   datetime64[ns]
#  1   SEX      8815 non-null   object
#  2   AGE      8763 non-null   float64
#  3   SYS      4914 non-null   float64
#  4   DIAS     4916 non-null   float64
#  5   EGFR     3317 non-null   object
#  6   ALT      3933 non-null   float64
#  7   FERR     2987 non-null   float64
#  8   CHOL     3454 non-null   float64
# dtypes: datetime64[ns](1), float64(6), object(2)
# memory usage: 619.9+ KB

# %% [markdown]
# ## **Exploratory Analysis**

# %%
df.describe()
# Out:
#                AGE          SYS         DIAS          ALT         FERR  \
# count  8763.000000  4914.000000  4916.000000  3933.000000  2987.000000
# mean     40.175625   122.161376    74.796379    26.798373   112.219417
# std      19.674870    15.799509    10.481735    25.729159   147.802723
# min       1.000000    71.000000    20.000000     5.000000     2.000000
# 25%      27.000000   111.000000    68.000000    16.000000    35.000000
# 50%      38.000000   121.000000    75.000000    21.000000    73.000000
# 75%      54.000000   131.000000    81.000000    31.000000   141.000000
# max     114.000000   212.000000   186.000000   831.000000  2994.000000
#
#               CHOL
# count  3454.000000
# mean      4.994268
# std       1.105231
# min       1.600000
# 25%       4.200000
# 50%       4.900000
# 75%       5.700000
# max      13.400000

# %%
sns.pairplot(df)

# %%
# %config InlineBackend.figure_format = 'retina'
plt.figure(figsize = (10, 10))

sns.heatmap(
    df.corr(), 
    cmap = 'crest', 
    annot = True, 
    annot_kws = {"size": 10}
)

# %%
sns.lmplot(data=df, x='DIAS', y='SYS', scatter_kws={"color": "#6a994e"}, size=8, line_kws={"color": "#bc4749"})
plt.title('Population Blood Pressure')
plt.xlabel('Diastolic Blood Pressure')
plt.ylabel('Systolic Blood Pressure')
plt.legend()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/regression.py:581: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
# WARNING:matplotlib.legend:No handles with labels found to put in legend.

# %%
sns.lmplot(data=df, x='AGE', y='SYS', scatter_kws={"color": "#6a994e"}, size=8, line_kws={"color": "#bc4749"})
plt.title('Population AGE v Systolic Blood Pressure')
plt.xlabel('AGE')
plt.ylabel('Systolic Blood Pressure')
plt.legend()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/regression.py:581: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
# WARNING:matplotlib.legend:No handles with labels found to put in legend.

# %%
fig = plt.figure(figsize=(20,11))

plt.subplot(2, 2, 1)
sns.violinplot(data=df[['CHOL']], color='#457b9d')

plt.subplot(2, 2, 2)
sns.violinplot(data=df[['ALT']], color='#6a994e')


plt.subplot(2, 2, 3)
sns.violinplot(data=df[['FERR']], color='#fb8500')


plt.subplot(2, 2, 4)
sns.violinplot(data=df[['AGE']], color='#219ebc')

plt.show()

# %% [markdown]
# # **Linear Regression** - Dep Variable: **SYSTOLIC BP**

# %%
features = [
    "AGE",
    "DIAS",
    "FERR",
    "CHOL",
    "ALT"
]

# %%
df_standardized = df.copy()
for f in features:
    mu = df[f].mean()
    sigma = df[f].std()
    df_standardized[f] = df[f].map(lambda x: (x - mu) / sigma)
df_standardized
# Out:
#         REGDATE     SEX       AGE    SYS      DIAS EGFR       ALT      FERR  \
# 0    2010-08-17  Female -1.381235    NaN       NaN  NaN       NaN -0.698359
# 1    2010-09-09  Female -1.432062    NaN       NaN  NaN       NaN       NaN
# 2    2014-07-17  Female -1.635367    NaN       NaN  NaN       NaN       NaN
# 3    2011-10-14  Female -1.482888    NaN       NaN  NaN       NaN       NaN
# 4    2020-05-07  Female -1.940324    NaN       NaN  NaN       NaN       NaN
# ...         ...     ...       ...    ...       ...  ...       ...       ...
# 8810 2017-09-15  Female -0.059753    NaN       NaN  NaN       NaN       NaN
# 8811 2019-10-15    Male -0.059753  128.0  0.591851  NaN       NaN       NaN
# 8812 2019-09-25  Female -0.720494  113.0 -0.552998   90 -0.225362 -0.671296
# 8813 2018-07-10    Male  0.346857  120.0  0.305638   90  0.629699  0.363867
# 8814 2022-01-20    Male -0.771320    NaN       NaN  NaN       NaN       NaN
#
#           CHOL
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
# ...        ...
# 8810       NaN
# 8811       NaN
# 8812 -0.447208
# 8813  0.005187
# 8814       NaN
#
# [8815 rows x 9 columns]

# %%
formula = "SYS ~ " + ' + '.join(features)
formula
# Out:
# 'SYS ~ AGE + DIAS + FERR + CHOL + ALT'

# %%
import statsmodels.formula.api as smf

model = smf.ols(formula = formula, data = df_standardized).fit()
print(model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    SYS   R-squared:                       0.445
# Model:                            OLS   Adj. R-squared:                  0.444
# Method:                 Least Squares   F-statistic:                     402.9
# Date:                Mon, 21 Nov 2022   Prob (F-statistic):          7.74e-318
# Time:                        04:58:51   Log-Likelihood:                -9789.2
# No. Observations:                2515   AIC:                         1.959e+04
# Df Residuals:                    2509   BIC:                         1.963e+04
# Df Model:                           5
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept    119.5945      0.280    427.807      0.000     119.046     120.143
# AGE            5.2254      0.265     19.747      0.000       4.706       5.744
# DIAS           8.8701      0.240     36.891      0.000       8.399       9.342
# FERR           0.3813      0.240      1.591      0.112      -0.089       0.851
# CHOL           0.0452      0.242      0.187      0.852      -0.429       0.520
# ALT            0.9605      0.272      3.536      0.000       0.428       1.493
# ==============================================================================
# Omnibus:                      208.540   Durbin-Watson:                   1.974
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1129.666
# Skew:                           0.163   Prob(JB):                    4.97e-246
# Kurtosis:                       6.267   Cond. No.                         1.94
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
model.params[1:].sort_values().plot(kind='barh')

# %%
predicted_SYS = model.predict(df_standardized[features])
residuals = predicted_SYS - df_standardized.SYS

# %%
rmse = (residuals**2).mean()**0.5
rmse
# Out:
# 11.862401442743732

# %%
sns.histplot(residuals, kde=True, stat='density', discrete=True, color='#00b4d8')
plt.title('residuals density plot')
# Out:
# Text(0.5, 1.0, 'residuals density plot')

# %%
sns.kdeplot(predicted_SYS, label='Predicted SYS BP')
sns.kdeplot(df.SYS, label = 'Actual SYS BP')
plt.title('Distribution of predicted v actual values')
plt.legend()

# %% [markdown]
# ### **Reg Plots** (DF Sample v DF Full) - DEP Variable: **SYSTOLIC BP**

# %%
sample = df.sample(800, random_state=42)

plt.figure(figsize=(13,5))
plt.suptitle('Regression of SYS BP, 95% confidence interval')

plt.subplot(1,2,1)
sns.regplot(x = sample.DIAS, y= sample.SYS, y_jitter=.1, ci=95, line_kws={"color": "#bc4749"})
plt.ylim(bottom=0)

plt.subplot(1,2,2)
sns.regplot(x = df.DIAS, y= df.SYS, y_jitter=.1, ci=95, line_kws={"color": "#bc4749"})
plt.ylim(bottom=0)
# Out:
# (0.0, 237.05921269104658)

# %%
sample = df.sample(500, random_state=42)

plt.figure(figsize=(13,5))
plt.suptitle('Regression of Diastolic BP given SYSTOLIC BP, 95% confidence interval')

plt.subplot(1,2,1)
sns.regplot(x = sample.AGE, y= sample.SYS, y_jitter=.1, ci=95, line_kws={"color": "#bc4749"})
plt.ylim(bottom=0)

plt.subplot(1,2,2)
sns.regplot(x = df.AGE, y= df.SYS, y_jitter=.1, ci=95, line_kws={"color": "#bc4749"})
plt.ylim(bottom=0)
# Out:
# (0.0, 219.08595577855945)

# %%
sample = df.sample(500, random_state=42)

plt.figure(figsize=(13,5))
plt.suptitle('Regression of CHOL given SYSTOLIC BP, 95% confidence interval')

plt.subplot(1,2,1)
sns.regplot(x = sample.CHOL, y= sample.SYS, y_jitter=.1, ci=95, line_kws={"color": "#bc4749"})
plt.ylim(bottom=0)

plt.subplot(1,2,2)
sns.regplot(x = df.CHOL, y= df.SYS, y_jitter=.1, ci=95, line_kws={"color": "#bc4749"})
plt.ylim(bottom=0)
# Out:
# (0.0, 207.380993943523)

# %%
sample = df.sample(500, random_state=42)

plt.figure(figsize=(13,5))
plt.suptitle('Regression of ALT given SYSTOLIC BP, 95% confidence interval')

plt.subplot(1,2,1)
sns.regplot(x = sample.ALT, y= sample.SYS, y_jitter=.1, ci=95, line_kws={"color": "#bc4749"})
plt.ylim(bottom=0)

plt.subplot(1,2,2)
sns.regplot(x = df.ALT, y= df.SYS, y_jitter=.1, ci=95, line_kws={"color": "#bc4749"})
plt.ylim(bottom=0)
# Out:
# (0.0, 225.69772239979045)

# %%
sample = df.sample(500, random_state=42)

plt.figure(figsize=(13,5))
plt.suptitle('Regression of FERR given SYSTOLIC BP, 95% confidence interval')

plt.subplot(1,2,1)
sns.regplot(x = sample.FERR, y= sample.SYS, y_jitter=.1, ci=95, line_kws={"color": "#bc4749"})
plt.ylim(bottom=0)

plt.subplot(1,2,2)
sns.regplot(x = df.FERR, y= df.SYS, y_jitter=.1, ci=95, line_kws={"color": "#bc4749"})
plt.ylim(bottom=0)
# Out:
# (0.0, 201.54619249716472)

# %% [markdown]
# # **Linear Regression** - Dep Variable: **AGE**

# %%
sns.lmplot(data=df, x='AGE', y='SYS', scatter_kws={"color": "#6a994e"}, size=8, line_kws={"color": "#bc4749"})
plt.title('Scatter Plot Age v SYS BP')
plt.xlabel('AGE')
plt.ylabel('Systolic Blood Pressure')
plt.legend()
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/regression.py:581: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
# WARNING:matplotlib.legend:No handles with labels found to put in legend.

# %%
features2 = [
    "SYS",
    "DIAS",
    "FERR",
    "CHOL",
    "ALT"
]

# %%
df_standardized2 = df.copy()
for f in features2:
    mu = df[f].mean()
    sigma = df[f].std()
    df_standardized2[f] = df[f].map(lambda x: (x - mu) / sigma)
df_standardized2
# Out:
#         REGDATE     SEX   AGE       SYS      DIAS EGFR       ALT      FERR  \
# 0    2010-08-17  Female  13.0       NaN       NaN  NaN       NaN -0.698359
# 1    2010-09-09  Female  12.0       NaN       NaN  NaN       NaN       NaN
# 2    2014-07-17  Female   8.0       NaN       NaN  NaN       NaN       NaN
# 3    2011-10-14  Female  11.0       NaN       NaN  NaN       NaN       NaN
# 4    2020-05-07  Female   2.0       NaN       NaN  NaN       NaN       NaN
# ...         ...     ...   ...       ...       ...  ...       ...       ...
# 8810 2017-09-15  Female  39.0       NaN       NaN  NaN       NaN       NaN
# 8811 2019-10-15    Male  39.0  0.369545  0.591851  NaN       NaN       NaN
# 8812 2019-09-25  Female  26.0 -0.579852 -0.552998   90 -0.225362 -0.671296
# 8813 2018-07-10    Male  47.0 -0.136800  0.305638   90  0.629699  0.363867
# 8814 2022-01-20    Male  25.0       NaN       NaN  NaN       NaN       NaN
#
#           CHOL
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
# ...        ...
# 8810       NaN
# 8811       NaN
# 8812 -0.447208
# 8813  0.005187
# 8814       NaN
#
# [8815 rows x 9 columns]

# %%
formula2 = "AGE ~ " + ' + '.join(features2)
formula2
# Out:
# 'AGE ~ SYS + DIAS + FERR + CHOL + ALT'

# %%
import statsmodels.formula.api as smf

model2 = smf.ols(formula = formula2, data = df_standardized2).fit()
print(model2.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    AGE   R-squared:                       0.193
# Model:                            OLS   Adj. R-squared:                  0.191
# Method:                 Least Squares   F-statistic:                     120.0
# Date:                Mon, 21 Nov 2022   Prob (F-statistic):          4.40e-114
# Time:                        05:02:25   Log-Likelihood:                -10601.
# No. Observations:                2515   AIC:                         2.121e+04
# Df Residuals:                    2509   BIC:                         2.125e+04
# Df Model:                           5
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     50.9816      0.328    155.488      0.000      50.339      51.625
# SYS            8.0024      0.405     19.747      0.000       7.208       8.797
# DIAS          -3.6845      0.406     -9.080      0.000      -4.480      -2.889
# FERR           3.2064      0.325      9.868      0.000       2.569       3.844
# CHOL           1.6632      0.333      5.001      0.000       1.011       2.315
# ALT           -2.2584      0.373     -6.049      0.000      -2.991      -1.526
# ==============================================================================
# Omnibus:                       45.284   Durbin-Watson:                   2.037
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               46.704
# Skew:                           0.322   Prob(JB):                     7.22e-11
# Kurtosis:                       2.825   Cond. No.                         2.07
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
model2.params[1:].sort_values().plot(kind='barh')

# %%
predicted_AGE = model2.predict(df_standardized2[features2])
residuals2 = predicted_AGE - df_standardized2.AGE

# %%
rmse = (residuals**2).mean()**0.5
rmse
# Out:
# 11.862401442743732

# %%
sns.histplot(residuals2, kde=True, stat='density', discrete=True, color='#00b4d8')
plt.title('Residuals density plot')
# Out:
# Text(0.5, 1.0, 'Residuals density plot')

# %%
sns.kdeplot(predicted_AGE, label='Predicted AGE')
sns.kdeplot(df.AGE, label = 'Actual AGE')
plt.title('Distribution of predicted v actual values')
plt.legend()

# %% [markdown]
# ### **Reg Plots** (DF Sample v DF Full) - DEP Variable: **AGE**

# %%
sample2 = df.sample(800, random_state=42)

plt.figure(figsize=(13,5))
plt.suptitle('Regression of SYS BP Given AGE, 95% confidence interval')

plt.subplot(1,2,1)
sns.regplot(x = sample2.SYS, y = sample2.AGE, y_jitter=.1, ci=95, line_kws={"color": "#bc4749"})
plt.ylim(bottom=0)

plt.subplot(1,2,2)
sns.regplot(x = df.SYS, y= df.AGE, y_jitter=.1, ci=95, line_kws={"color": "#bc4749"})
plt.ylim(bottom=0)
# Out:
# (0.0, 119.55971538087704)

# %%
sample2 = df.sample(800, random_state=42)

plt.figure(figsize=(13,5))
plt.suptitle('Regression of DIASTOLIC BP Given AGE, 95% confidence interval')

plt.subplot(1,2,1)
sns.regplot(x = sample2.DIAS, y = sample2.AGE, y_jitter=.1, ci=95, line_kws={"color": "#bc4749"})
plt.ylim(bottom=0)

plt.subplot(1,2,2)
sns.regplot(x = df.DIAS, y= df.AGE, y_jitter=.1, ci=95, line_kws={"color": "#bc4749"})
plt.ylim(bottom=0)
# Out:
# (0.0, 119.44619225983047)

# %%
sample2 = df.sample(800, random_state=42)

plt.figure(figsize=(13,5))
plt.suptitle('Regression of CHOL Given AGE, 95% confidence interval')

plt.subplot(1,2,1)
sns.regplot(x = sample2.CHOL, y = sample2.AGE, y_jitter=.1, ci=95, line_kws={"color": "#bc4749"})
plt.ylim(bottom=0)

plt.subplot(1,2,2)
sns.regplot(x = df.CHOL, y= df.AGE, y_jitter=.1, ci=95, line_kws={"color": "#bc4749"})
plt.ylim(bottom=0)
# Out:
# (0.0, 109.95205535391074)

# %%
sample2 = df.sample(800, random_state=42)

plt.figure(figsize=(13,5))
plt.suptitle('Regression of ALT Given AGE, 95% confidence interval')

plt.subplot(1,2,1)
sns.regplot(x = sample2.ALT, y = sample2.AGE, y_jitter=.1, ci=95, line_kws={"color": "#bc4749"})
plt.ylim(bottom=0)

plt.subplot(1,2,2)
sns.regplot(x = df.ALT, y= df.AGE, y_jitter=.1, ci=95, line_kws={"color": "#bc4749"})
plt.ylim(bottom=0)
# Out:
# (0.0, 110.22290326572774)

# %%
sample2 = df.sample(800, random_state=42)

plt.figure(figsize=(13,5))
plt.suptitle('Regression of Ferritin Given AGE, 95% confidence interval')

plt.subplot(1,2,1)
sns.regplot(x = sample2.FERR, y = sample2.AGE, y_jitter=.1, ci=95, line_kws={"color": "#bc4749"})
plt.ylim(bottom=0)

plt.subplot(1,2,2)
sns.regplot(x = df.FERR, y= df.AGE, y_jitter=.1, ci=95, line_kws={"color": "#bc4749"})
plt.ylim(bottom=0)
# Out:
# (0.0, 174.34907174461543)
